# %%
import re
import warnings
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/Users/yangyang/Desktop/DS/raw_data/emails2.csv')
df
# Out:
#         Unnamed: 0                       file  \
# 0                0      allen-p/_sent_mail/1.
# 1                1     allen-p/_sent_mail/10.
# 2                2    allen-p/_sent_mail/100.
# 3                3   allen-p/_sent_mail/1000.
# 4                4   allen-p/_sent_mail/1001.
# 5                5   allen-p/_sent_mail/1002.
# 6                6   allen-p/_sent_mail/1003.
# 7                7   allen-p/_sent_mail/1004.
# 8                8    allen-p/_sent_mail/101.
# 9                9    allen-p/_sent_mail/102.
# 10              10    allen-p/_sent_mail/103.
# 11              11    allen-p/_sent_mail/104.
# 12              12    allen-p/_sent_mail/105.
# 13              13    allen-p/_sent_mail/106.
# 14              14    allen-p/_sent_mail/107.
# 15              15    allen-p/_sent_mail/108.
# 16              16    allen-p/_sent_mail/109.
# 17              17     allen-p/_sent_mail/11.
# 18              18    allen-p/_sent_mail/110.
# 19              19    allen-p/_sent_mail/111.
# 20              20    allen-p/_sent_mail/112.
# 21              21    allen-p/_sent_mail/113.
# 22              22    allen-p/_sent_mail/114.
# 23              23    allen-p/_sent_mail/115.
# 24              24    allen-p/_sent_mail/116.
# 25              25    allen-p/_sent_mail/117.
# 26              26    allen-p/_sent_mail/118.
# 27              27    allen-p/_sent_mail/119.
# 28              28     allen-p/_sent_mail/12.
# 29              29    allen-p/_sent_mail/120.
# ...            ...                        ...
# 517371      517371  zufferli-j/sent_items/72.
# 517372      517372  zufferli-j/sent_items/73.
# 517373      517373  zufferli-j/sent_items/74.
# 517374      517374  zufferli-j/sent_items/75.
# 517375      517375  zufferli-j/sent_items/76.
# 517376      517376  zufferli-j/sent_items/77.
# 517377      517377  zufferli-j/sent_items/78.
# 517378      517378  zufferli-j/sent_items/79.
# 517379      517379   zufferli-j/sent_items/8.
# 517380      517380  zufferli-j/sent_items/80.
# 517381      517381  zufferli-j/sent_items/81.
# 517382      517382  zufferli-j/sent_items/82.
# 517383      517383  zufferli-j/sent_items/83.
# 517384      517384  zufferli-j/sent_items/84.
# 517385      517385  zufferli-j/sent_items/85.
# 517386      517386  zufferli-j/sent_items/86.
# 517387      517387  zufferli-j/sent_items/87.
# 517388      517388  zufferli-j/sent_items/88.
# 517389      517389  zufferli-j/sent_items/89.
# 517390      517390   zufferli-j/sent_items/9.
# 517391      517391  zufferli-j/sent_items/90.
# 517392      517392  zufferli-j/sent_items/91.
# 517393      517393  zufferli-j/sent_items/92.
# 517394      517394  zufferli-j/sent_items/93.
# 517395      517395  zufferli-j/sent_items/94.
# 517396      517396  zufferli-j/sent_items/95.
# 517397      517397  zufferli-j/sent_items/96.
# 517398      517398  zufferli-j/sent_items/97.
# 517399      517399  zufferli-j/sent_items/98.
# 517400      517400  zufferli-j/sent_items/99.
#
#                                            Message-ID  \
# 0       <18782981.1075855378110.JavaMail.evans@thyme>
# 1       <15464986.1075855378456.JavaMail.evans@thyme>
# 2       <24216240.1075855687451.JavaMail.evans@thyme>
# 3       <13505866.1075863688222.JavaMail.evans@thyme>
# 4       <30922949.1075863688243.JavaMail.evans@thyme>
# 5       <30965995.1075863688265.JavaMail.evans@thyme>
# 6       <16254169.1075863688286.JavaMail.evans@thyme>
# 7       <17189699.1075863688308.JavaMail.evans@thyme>
# 8       <20641191.1075855687472.JavaMail.evans@thyme>
# 9       <30795301.1075855687494.JavaMail.evans@thyme>
# 10      <33076797.1075855687515.JavaMail.evans@thyme>
# 11      <25459584.1075855687536.JavaMail.evans@thyme>
# 12      <13116875.1075855687561.JavaMail.evans@thyme>
# 13       <2707340.1075855687584.JavaMail.evans@thyme>
# 14       <2465689.1075855687605.JavaMail.evans@thyme>
# 15       <1115198.1075855687626.JavaMail.evans@thyme>
# 16      <19773657.1075855687649.JavaMail.evans@thyme>
# 17       <7391389.1075855378477.JavaMail.evans@thyme>
# 18      <12759088.1075855687671.JavaMail.evans@thyme>
# 19      <29177675.1075855687692.JavaMail.evans@thyme>
# 20      <24729148.1075855687713.JavaMail.evans@thyme>
# 21      <17610321.1075855687735.JavaMail.evans@thyme>
# 22      <26575732.1075855687756.JavaMail.evans@thyme>
# 23      <15294346.1075855687778.JavaMail.evans@thyme>
# 24      <25140503.1075855687800.JavaMail.evans@thyme>
# 25      <19034252.1075855687825.JavaMail.evans@thyme>
# 26        <719350.1075855687850.JavaMail.evans@thyme>
# 27      <10523086.1075855687873.JavaMail.evans@thyme>
# 28       <8572706.1075855378498.JavaMail.evans@thyme>
# 29      <29665600.1075855687895.JavaMail.evans@thyme>
# ...                                               ...
# 517371    <537849.1075842029343.JavaMail.evans@thyme>
# 517372  <13493029.1075842029366.JavaMail.evans@thyme>
# 517373  <16498082.1075842029389.JavaMail.evans@thyme>
# 517374  <22995838.1075842029414.JavaMail.evans@thyme>
# 517375  <11108760.1075842029437.JavaMail.evans@thyme>
# 517376   <8076849.1075842029460.JavaMail.evans@thyme>
# 517377  <19930331.1075842029483.JavaMail.evans@thyme>
# 517378  <28740402.1075842029506.JavaMail.evans@thyme>
# 517379  <18413789.1075842027754.JavaMail.evans@thyme>
# 517380  <23888524.1075842029528.JavaMail.evans@thyme>
# 517381  <15646538.1075842029551.JavaMail.evans@thyme>
# 517382   <5288057.1075842029577.JavaMail.evans@thyme>
# 517383  <24246770.1075842029601.JavaMail.evans@thyme>
# 517384  <30449512.1075842029649.JavaMail.evans@thyme>
# 517385  <26316757.1075842029675.JavaMail.evans@thyme>
# 517386  <24771639.1075842029703.JavaMail.evans@thyme>
# 517387  <27114536.1075842029725.JavaMail.evans@thyme>
# 517388  <11279427.1075842029748.JavaMail.evans@thyme>
# 517389  <24358278.1075842029773.JavaMail.evans@thyme>
# 517390   <8033934.1075842027777.JavaMail.evans@thyme>
# 517391  <25508136.1075842029796.JavaMail.evans@thyme>
# 517392  <23829224.1075842029820.JavaMail.evans@thyme>
# 517393  <25622034.1075842029843.JavaMail.evans@thyme>
# 517394  <25507923.1075842029891.JavaMail.evans@thyme>
# 517395  <20245656.1075842029914.JavaMail.evans@thyme>
# 517396  <26807948.1075842029936.JavaMail.evans@thyme>
# 517397  <25835861.1075842029959.JavaMail.evans@thyme>
# 517398  <28979867.1075842029988.JavaMail.evans@thyme>
# 517399  <22052556.1075842030013.JavaMail.evans@thyme>
# 517400  <28618979.1075842030037.JavaMail.evans@thyme>
#
#                                          Date  \
# 0       Mon, 14 May 2001 16:39:00 -0700 (PDT)
# 1        Fri, 4 May 2001 13:51:00 -0700 (PDT)
# 2       Wed, 18 Oct 2000 03:00:00 -0700 (PDT)
# 3       Mon, 23 Oct 2000 06:13:00 -0700 (PDT)
# 4       Thu, 31 Aug 2000 05:07:00 -0700 (PDT)
# 5       Thu, 31 Aug 2000 04:17:00 -0700 (PDT)
# 6       Tue, 22 Aug 2000 07:44:00 -0700 (PDT)
# 7       Fri, 14 Jul 2000 06:59:00 -0700 (PDT)
# 8       Tue, 17 Oct 2000 02:26:00 -0700 (PDT)
# 9       Mon, 16 Oct 2000 06:44:00 -0700 (PDT)
# 10      Mon, 16 Oct 2000 06:42:00 -0700 (PDT)
# 11      Fri, 13 Oct 2000 06:45:00 -0700 (PDT)
# 12       Mon, 9 Oct 2000 07:16:00 -0700 (PDT)
# 13       Mon, 9 Oct 2000 07:00:00 -0700 (PDT)
# 14       Thu, 5 Oct 2000 06:26:00 -0700 (PDT)
# 15       Thu, 5 Oct 2000 05:55:00 -0700 (PDT)
# 16       Wed, 4 Oct 2000 09:23:00 -0700 (PDT)
# 17       Fri, 4 May 2001 11:26:00 -0700 (PDT)
# 18       Tue, 3 Oct 2000 09:30:00 -0700 (PDT)
# 19       Tue, 3 Oct 2000 09:15:00 -0700 (PDT)
# 20       Tue, 3 Oct 2000 09:13:00 -0700 (PDT)
# 21       Tue, 3 Oct 2000 03:17:00 -0700 (PDT)
# 22       Mon, 2 Oct 2000 02:19:00 -0700 (PDT)
# 23      Thu, 28 Sep 2000 06:17:00 -0700 (PDT)
# 24      Thu, 28 Sep 2000 05:56:00 -0700 (PDT)
# 25      Tue, 26 Sep 2000 09:28:00 -0700 (PDT)
# 26      Tue, 26 Sep 2000 09:26:00 -0700 (PDT)
# 27      Tue, 26 Sep 2000 07:01:00 -0700 (PDT)
# 28       Thu, 3 May 2001 15:57:00 -0700 (PDT)
# 29      Tue, 26 Sep 2000 05:11:00 -0700 (PDT)
# ...                                       ...
# 517371   Mon, 7 Jan 2002 13:01:08 -0800 (PST)
# 517372   Wed, 2 Jan 2002 09:55:40 -0800 (PST)
# 517373  Fri, 21 Dec 2001 12:46:09 -0800 (PST)
# 517374  Fri, 21 Dec 2001 12:44:08 -0800 (PST)
# 517375  Fri, 21 Dec 2001 12:34:51 -0800 (PST)
# 517376  Fri, 21 Dec 2001 09:05:05 -0800 (PST)
# 517377  Thu, 20 Dec 2001 13:23:27 -0800 (PST)
# 517378  Thu, 20 Dec 2001 09:51:58 -0800 (PST)
# 517379   Tue, 5 Feb 2002 15:18:24 -0800 (PST)
# 517380  Mon, 17 Dec 2001 07:25:14 -0800 (PST)
# 517381  Mon, 17 Dec 2001 06:38:26 -0800 (PST)
# 517382  Fri, 14 Dec 2001 10:23:43 -0800 (PST)
# 517383  Thu, 13 Dec 2001 13:00:16 -0800 (PST)
# 517384  Wed, 12 Dec 2001 09:14:32 -0800 (PST)
# 517385  Tue, 11 Dec 2001 09:49:12 -0800 (PST)
# 517386  Tue, 11 Dec 2001 09:48:22 -0800 (PST)
# 517387   Fri, 7 Dec 2001 13:11:09 -0800 (PST)
# 517388   Fri, 7 Dec 2001 12:28:58 -0800 (PST)
# 517389   Fri, 7 Dec 2001 07:36:04 -0800 (PST)
# 517390   Tue, 5 Feb 2002 15:02:45 -0800 (PST)
# 517391   Wed, 5 Dec 2001 06:22:58 -0800 (PST)
# 517392   Mon, 3 Dec 2001 05:53:41 -0800 (PST)
# 517393  Fri, 30 Nov 2001 14:53:21 -0800 (PST)
# 517394  Thu, 29 Nov 2001 11:41:51 -0800 (PST)
# 517395  Thu, 29 Nov 2001 11:04:24 -0800 (PST)
# 517396  Wed, 28 Nov 2001 13:30:11 -0800 (PST)
# 517397  Wed, 28 Nov 2001 12:47:48 -0800 (PST)
# 517398  Wed, 28 Nov 2001 07:20:00 -0800 (PST)
# 517399  Tue, 27 Nov 2001 11:52:45 -0800 (PST)
# 517400  Mon, 26 Nov 2001 10:48:43 -0800 (PST)
#
#                                           From  \
# 0       frozenset({'phillip.allen@enron.com'})
# 1       frozenset({'phillip.allen@enron.com'})
# 2       frozenset({'phillip.allen@enron.com'})
# 3       frozenset({'phillip.allen@enron.com'})
# 4       frozenset({'phillip.allen@enron.com'})
# 5       frozenset({'phillip.allen@enron.com'})
# 6       frozenset({'phillip.allen@enron.com'})
# 7       frozenset({'phillip.allen@enron.com'})
# 8       frozenset({'phillip.allen@enron.com'})
# 9       frozenset({'phillip.allen@enron.com'})
# 10      frozenset({'phillip.allen@enron.com'})
# 11      frozenset({'phillip.allen@enron.com'})
# 12      frozenset({'phillip.allen@enron.com'})
# 13      frozenset({'phillip.allen@enron.com'})
# 14      frozenset({'phillip.allen@enron.com'})
# 15      frozenset({'phillip.allen@enron.com'})
# 16      frozenset({'phillip.allen@enron.com'})
# 17      frozenset({'phillip.allen@enron.com'})
# 18      frozenset({'phillip.allen@enron.com'})
# 19      frozenset({'phillip.allen@enron.com'})
# 20      frozenset({'phillip.allen@enron.com'})
# 21      frozenset({'phillip.allen@enron.com'})
# 22      frozenset({'phillip.allen@enron.com'})
# 23      frozenset({'phillip.allen@enron.com'})
# 24      frozenset({'phillip.allen@enron.com'})
# 25      frozenset({'phillip.allen@enron.com'})
# 26      frozenset({'phillip.allen@enron.com'})
# 27      frozenset({'phillip.allen@enron.com'})
# 28      frozenset({'phillip.allen@enron.com'})
# 29      frozenset({'phillip.allen@enron.com'})
# ...                                        ...
# 517371  frozenset({'john.zufferli@enron.com'})
# 517372  frozenset({'john.zufferli@enron.com'})
# 517373  frozenset({'john.zufferli@enron.com'})
# 517374  frozenset({'john.zufferli@enron.com'})
# 517375  frozenset({'john.zufferli@enron.com'})
# 517376  frozenset({'john.zufferli@enron.com'})
# 517377  frozenset({'john.zufferli@enron.com'})
# 517378  frozenset({'john.zufferli@enron.com'})
# 517379  frozenset({'john.zufferli@enron.com'})
# 517380  frozenset({'john.zufferli@enron.com'})
# 517381  frozenset({'john.zufferli@enron.com'})
# 517382  frozenset({'john.zufferli@enron.com'})
# 517383  frozenset({'john.zufferli@enron.com'})
# 517384  frozenset({'john.zufferli@enron.com'})
# 517385  frozenset({'john.zufferli@enron.com'})
# 517386  frozenset({'john.zufferli@enron.com'})
# 517387  frozenset({'john.zufferli@enron.com'})
# 517388  frozenset({'john.zufferli@enron.com'})
# 517389  frozenset({'john.zufferli@enron.com'})
# 517390  frozenset({'john.zufferli@enron.com'})
# 517391  frozenset({'john.zufferli@enron.com'})
# 517392  frozenset({'john.zufferli@enron.com'})
# 517393  frozenset({'john.zufferli@enron.com'})
# 517394  frozenset({'john.zufferli@enron.com'})
# 517395  frozenset({'john.zufferli@enron.com'})
# 517396  frozenset({'john.zufferli@enron.com'})
# 517397  frozenset({'john.zufferli@enron.com'})
# 517398  frozenset({'john.zufferli@enron.com'})
# 517399  frozenset({'john.zufferli@enron.com'})
# 517400  frozenset({'john.zufferli@enron.com'})
#
#                                                        To  \
# 0                     frozenset({'tim.belden@enron.com'})
# 1                  frozenset({'john.lavorato@enron.com'})
# 2                   frozenset({'leah.arsdall@enron.com'})
# 3                    frozenset({'randall.gay@enron.com'})
# 4                     frozenset({'greg.piper@enron.com'})
# 5                     frozenset({'greg.piper@enron.com'})
# 6       frozenset({'david.l.johnson@enron.com', 'john....
# 7                 frozenset({'joyce.teixeira@enron.com'})
# 8                     frozenset({'mark.scott@enron.com'})
# 9                          frozenset({'zimam@enron.com'})
# 10              frozenset({'buck.buckner@honeywell.com'})
# 11              frozenset({'stagecoachmama@hotmail.com'})
# 12                   frozenset({'keith.holst@enron.com'})
# 13                   frozenset({'keith.holst@enron.com'})
# 14                frozenset({'david.delainey@enron.com'})
# 15                  frozenset({'paula.harris@enron.com'})
# 16                    frozenset({'ina.rangel@enron.com'})
# 17               frozenset({'tim.heizenrader@enron.com'})
# 18                    frozenset({'pallen70@hotmail.com'})
# 19                    frozenset({'ina.rangel@enron.com'})
# 20                      frozenset({'bs_stone@yahoo.com'})
# 21               frozenset({'stouchstone@natsource.com'})
# 22                      frozenset({'bs_stone@yahoo.com'})
# 23                            frozenset({'lkuch@mh.com'})
# 24                 frozenset({'jeffrey.hodge@enron.com'})
# 25                        frozenset({'kholst@enron.com'})
# 26                    frozenset({'pallen70@hotmail.com'})
# 27                    frozenset({'ina.rangel@enron.com'})
# 28                      frozenset({'rlehmann@yahoo.com'})
# 29               frozenset({'cindy.cicchetti@enron.com'})
# ...                                                   ...
# 517371          frozenset({'livia_zufferli@monitor.com'})
# 517372            frozenset({'frank.senders@pandora.be'})
# 517373                frozenset({'mark.dupuy@enron.com'})
# 517374       frozenset({'karen.mazuryk@powerpool.ab.ca'})
# 517375       frozenset({'karen.mazuryk@powerpool.ab.ca'})
# 517376          frozenset({'livia_zufferli@monitor.com'})
# 517377             frozenset({'rob.milnthorp@enron.com'})
# 517378           frozenset({'stephanie.sever@enron.com'})
# 517379               frozenset({'janet.mulero@ubsw.com'})
# 517380                   frozenset({'jzufferli@shaw.ca'})
# 517381                frozenset({'c..koehler@enron.com'})
# 517382          frozenset({'livia_zufferli@monitor.com'})
# 517383                frozenset({'c..koehler@enron.com'})
# 517384       frozenset({'astrid.montes@powerpool.ab.ca'})
# 517385             frozenset({'cooper.richey@enron.com'})
# 517386                   frozenset({'jzufferli@shaw.ca'})
# 517387               frozenset({'dawn.doucet@enron.com'})
# 517388            frozenset({'louise.kitchen@enron.com'})
# 517389         frozenset({'ken.gardner@powerpool.ab.ca'})
# 517390        frozenset({'john.postlethwaite@enron.com'})
# 517391                frozenset({'lon.draper@enron.com'})
# 517392  frozenset({'gerry.hrap@enron.com', 'howard.san...
# 517393                   frozenset({'jzufferli@shaw.ca'})
# 517394                   frozenset({'jzufferli@shaw.ca'})
# 517395          frozenset({'livia_zufferli@monitor.com'})
# 517396                frozenset({'kori.loibl@enron.com'})
# 517397             frozenset({'john.lavorato@enron.com'})
# 517398               frozenset({'dawn.doucet@enron.com'})
# 517399              frozenset({'jeanie.slone@enron.com'})
# 517400          frozenset({'livia_zufferli@monitor.com'})
#
#                                                   Subject  Mime-Version  \
# 0                                                     NaN           1.0
# 1                                                     Re:           1.0
# 2                                                Re: test           1.0
# 3                                                     NaN           1.0
# 4                                               Re: Hello           1.0
# 5                                               Re: Hello           1.0
# 6                                                     NaN           1.0
# 7                            Re: PRC review - phone calls           1.0
# 8                          Re: High Speed Internet Access           1.0
# 9       FW: fixed forward or other Collar floor gas pr...           1.0
# 10      Re: FW: fixed forward or other Collar floor ga...           1.0
# 11                                                    NaN           1.0
# 12            Consolidated positions: Issues & To Do list           1.0
# 13            Consolidated positions: Issues & To Do list           1.0
# 14                                                    NaN           1.0
# 15                                   Re: 2001 Margin Plan           1.0
# 16                   Var, Reporting and Resources Meeting           1.0
# 17                                                    NaN           1.0
# 18                                               Westgate           1.0
# 19             Meeting re: Storage Strategies in the West           1.0
# 20                                                    NaN           1.0
# 21                             Re: Not business related..           1.0
# 22                        Re: Original Sept check/closing           1.0
# 23                                         San Juan Index           1.0
# 24                                         San Juan Index           1.0
# 25                                   Investment Structure           1.0
# 26                                   Investment Structure           1.0
# 27                                                    NaN           1.0
# 28                                                    NaN           1.0
# 29                         Re: Gas Trading Vision meeting           1.0
# ...                                                   ...           ...
# 517371                                                RE:           1.0
# 517372                                           Training           1.0
# 517373                           RE: W/C Deficiency Rider           1.0
# 517374                            RE: Lethbrige Ironworks           1.0
# 517375                                Lethbrige Ironworks           1.0
# 517376                                 RE: quick question           1.0
# 517377  RE: New Company - Online Trader Access (Stack ...           1.0
# 517378                           Gas and Power EOL Access           1.0
# 517379      RE: Market Risk Meeting Today - John Zufferli           1.0
# 517380                                                FW:           1.0
# 517381                        FW: I:\NewCo file inventory           1.0
# 517382                                                RE:           1.0
# 517383                                          RE: NETCO           1.0
# 517384                        Digital Certificate for TAU           1.0
# 517385  FW: Generation Maintenance Planning and Relate...           1.0
# 517386                                          FW: hello           1.0
# 517387                          FW: Strictly Confidential           1.0
# 517388                          FW: Strictly Confidential           1.0
# 517389                    RE: Supply Shortfall Procedures           1.0
# 517390          RE: EOL - Multiple Trading Books (URGENT)           1.0
# 517391                     FW: Positions without Sundance           1.0
# 517392                              RE: Counterparty List           1.0
# 517393                                                RE:           1.0
# 517394                                          FW: Hello           1.0
# 517395                                                RE:           1.0
# 517396                           Trade with John Lavorato           1.0
# 517397                                         Gas Hedges           1.0
# 517398                                   RE: CONFIDENTIAL           1.0
# 517399                          Calgary Analyst/Associate           1.0
# 517400                                   RE: ali's essays           1.0
#
#                         Content-Type Content-Transfer-Encoding  \
# 0       text/plain; charset=us-ascii                      7bit
# 1       text/plain; charset=us-ascii                      7bit
# 2       text/plain; charset=us-ascii                      7bit
# 3       text/plain; charset=us-ascii                      7bit
# 4       text/plain; charset=us-ascii                      7bit
# 5       text/plain; charset=us-ascii                      7bit
# 6       text/plain; charset=us-ascii                      7bit
# 7       text/plain; charset=us-ascii                      7bit
# 8       text/plain; charset=us-ascii                      7bit
# 9       text/plain; charset=us-ascii                      7bit
# 10      text/plain; charset=us-ascii                      7bit
# 11      text/plain; charset=us-ascii                      7bit
# 12      text/plain; charset=us-ascii                      7bit
# 13      text/plain; charset=us-ascii                      7bit
# 14      text/plain; charset=us-ascii                      7bit
# 15      text/plain; charset=us-ascii                      7bit
# 16      text/plain; charset=us-ascii                      7bit
# 17      text/plain; charset=us-ascii                      7bit
# 18      text/plain; charset=us-ascii                      7bit
# 19      text/plain; charset=us-ascii                      7bit
# 20      text/plain; charset=us-ascii                      7bit
# 21      text/plain; charset=us-ascii                      7bit
# 22      text/plain; charset=us-ascii                      7bit
# 23      text/plain; charset=us-ascii                      7bit
# 24      text/plain; charset=us-ascii                      7bit
# 25      text/plain; charset=us-ascii                      7bit
# 26      text/plain; charset=us-ascii                      7bit
# 27      text/plain; charset=us-ascii                      7bit
# 28      text/plain; charset=us-ascii                      7bit
# 29      text/plain; charset=us-ascii                      7bit
# ...                              ...                       ...
# 517371  text/plain; charset=us-ascii                      7bit
# 517372  text/plain; charset=us-ascii                      7bit
# 517373  text/plain; charset=us-ascii                      7bit
# 517374  text/plain; charset=us-ascii                      7bit
# 517375  text/plain; charset=us-ascii                      7bit
# 517376  text/plain; charset=us-ascii                      7bit
# 517377  text/plain; charset=us-ascii                      7bit
# 517378  text/plain; charset=us-ascii                      7bit
# 517379  text/plain; charset=us-ascii                      7bit
# 517380  text/plain; charset=us-ascii                      7bit
# 517381  text/plain; charset=us-ascii                      7bit
# 517382  text/plain; charset=us-ascii                      7bit
# 517383  text/plain; charset=us-ascii          quoted-printable
# 517384  text/plain; charset=us-ascii                      7bit
# 517385  text/plain; charset=us-ascii                      7bit
# 517386  text/plain; charset=us-ascii                      7bit
# 517387  text/plain; charset=us-ascii                      7bit
# 517388  text/plain; charset=us-ascii                      7bit
# 517389  text/plain; charset=us-ascii                      7bit
# 517390  text/plain; charset=us-ascii                      7bit
# 517391  text/plain; charset=us-ascii                      7bit
# 517392  text/plain; charset=us-ascii                      7bit
# 517393  text/plain; charset=us-ascii                      7bit
# 517394  text/plain; charset=us-ascii                      7bit
# 517395  text/plain; charset=us-ascii                      7bit
# 517396  text/plain; charset=us-ascii                      7bit
# 517397  text/plain; charset=us-ascii                      7bit
# 517398  text/plain; charset=us-ascii                      7bit
# 517399  text/plain; charset=us-ascii                      7bit
# 517400  text/plain; charset=us-ascii                      7bit
#
#                                                    X-From  \
# 0                                         Phillip K Allen
# 1                                         Phillip K Allen
# 2                                         Phillip K Allen
# 3                                         Phillip K Allen
# 4                                         Phillip K Allen
# 5                                         Phillip K Allen
# 6                                         Phillip K Allen
# 7                                         Phillip K Allen
# 8                                         Phillip K Allen
# 9                                         Phillip K Allen
# 10                                        Phillip K Allen
# 11                                        Phillip K Allen
# 12                                        Phillip K Allen
# 13                                        Phillip K Allen
# 14                                        Phillip K Allen
# 15                                        Phillip K Allen
# 16                                        Phillip K Allen
# 17                                        Phillip K Allen
# 18                                        Phillip K Allen
# 19                                        Phillip K Allen
# 20                                        Phillip K Allen
# 21                                        Phillip K Allen
# 22                                        Phillip K Allen
# 23                                        Phillip K Allen
# 24                                        Phillip K Allen
# 25                                        Phillip K Allen
# 26                                        Phillip K Allen
# 27                                        Phillip K Allen
# 28                                        Phillip K Allen
# 29                                        Phillip K Allen
# ...                                                   ...
# 517371  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517372  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517373  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517374  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517375  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517376  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517377  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517378  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517379  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517380  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517381  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517382  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517383  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517384  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517385  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517386  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517387  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517388  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517389  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517390  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517391  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517392  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517393  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517394  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517395  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517396  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517397  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517398  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517399  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517400  Zufferli, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
#
#                                                      X-To  \
# 0                Tim Belden <Tim Belden/Enron@EnronXGate>
# 1       John J Lavorato <John J Lavorato/ENRON@enronXg...
# 2                                        Leah Van Arsdall
# 3                                           Randall L Gay
# 4                                              Greg Piper
# 5                                              Greg Piper
# 6                  david.l.johnson@enron.com, John Shafer
# 7                                          Joyce Teixeira
# 8                                              Mark Scott
# 9                                         zimam@enron.com
# 10      "Buckner, Buck" <buck.buckner@honeywell.com> @...
# 11                             stagecoachmama@hotmail.com
# 12                                            Keith Holst
# 13                                            Keith Holst
# 14                                       David W Delainey
# 15                                           Paula Harris
# 16                                             Ina Rangel
# 17      Tim Heizenrader <Tim Heizenrader/Enron@EnronXG...
# 18                                   pallen70@hotmail.com
# 19                                             Ina Rangel
# 20                                     bs_stone@yahoo.com
# 21           Steve Touchstone <STouchstone@natsource.com>
# 22                "BS Stone" <bs_stone@yahoo.com> @ ENRON
# 23                                           Lkuch@mh.com
# 24                                        Jeffrey T Hodge
# 25                                       kholst@enron.com
# 26                                   pallen70@hotmail.com
# 27                                             Ina Rangel
# 28                          rlehmann <rlehmann@yahoo.com>
# 29                                        Cindy Cicchetti
# ...                                                   ...
# 517371                 'Livia_Zufferli@Monitor.com@ENRON'
# 517372                         'frank.senders@pandora.be'
# 517373  Dupuy, Mark </O=ENRON/OU=NA/CN=RECIPIENTS/CN=M...
# 517374              'karen.mazuryk@powerpool.ab.ca@ENRON'
# 517375                    'karen.mazuryk@powerpool.ab.ca'
# 517376                 'Livia_Zufferli@Monitor.com@ENRON'
# 517377  Milnthorp, Rob </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517378  Sever, Stephanie </O=ENRON/OU=NA/CN=RECIPIENTS...
# 517379                      'Janet.Mulero@ubsw.com@ENRON'
# 517380                                'jzufferli@shaw.ca'
# 517381  Koehler, Anne C. </O=ENRON/OU=NA/CN=RECIPIENTS...
# 517382                 'Livia_Zufferli@Monitor.com@ENRON'
# 517383  Koehler, Anne C. </O=ENRON/OU=NA/CN=RECIPIENTS...
# 517384                    'astrid.montes@powerpool.ab.ca'
# 517385  Richey, Cooper </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517386                                'jzufferli@shaw.ca'
# 517387  Doucet, Dawn </O=ENRON/OU=NA/CN=RECIPIENTS/CN=...
# 517388  Kitchen, Louise </O=ENRON/OU=NA/CN=RECIPIENTS/...
# 517389                      'ken.gardner@powerpool.ab.ca'
# 517390  Postlethwaite, John </O=ENRON/OU=NA/CN=RECIPIE...
# 517391  Draper, Lon </O=ENRON/OU=NA/CN=RECIPIENTS/CN=L...
# 517392  Laporte, Nicole </O=ENRON/OU=NA/CN=RECIPIENTS/...
# 517393           'J&J Zufferli <jzufferli@shaw.ca>@ENRON'
# 517394                                'jzufferli@shaw.ca'
# 517395                 'Livia_Zufferli@Monitor.com@ENRON'
# 517396  Loibl, Kori </O=ENRON/OU=NA/CN=RECIPIENTS/CN=K...
# 517397  Lavorato, John </O=ENRON/OU=NA/CN=RECIPIENTS/C...
# 517398  Doucet, Dawn </O=ENRON/OU=NA/CN=RECIPIENTS/CN=...
# 517399  Slone, Jeanie </O=ENRON/OU=NA/CN=RECIPIENTS/CN...
# 517400                 'Livia_Zufferli@Monitor.com@ENRON'
#
#                             X-cc X-bcc  \
# 0                            NaN   NaN
# 1                            NaN   NaN
# 2                            NaN   NaN
# 3                            NaN   NaN
# 4                            NaN   NaN
# 5                            NaN   NaN
# 6                            NaN   NaN
# 7                            NaN   NaN
# 8                            NaN   NaN
# 9                            NaN   NaN
# 10                           NaN   NaN
# 11                           NaN   NaN
# 12                           NaN   NaN
# 13                           NaN   NaN
# 14                           NaN   NaN
# 15                           NaN   NaN
# 16                           NaN   NaN
# 17                           NaN   NaN
# 18                           NaN   NaN
# 19                           NaN   NaN
# 20                           NaN   NaN
# 21                           NaN   NaN
# 22                           NaN   NaN
# 23                           NaN   NaN
# 24                           NaN   NaN
# 25                           NaN   NaN
# 26                           NaN   NaN
# 27                           NaN   NaN
# 28                           NaN   NaN
# 29                           NaN   NaN
# ...                          ...   ...
# 517371       'jzufferli@shaw.ca'   NaN
# 517372                       NaN   NaN
# 517373                       NaN   NaN
# 517374                       NaN   NaN
# 517375  'katrina@valeopower.com'   NaN
# 517376                       NaN   NaN
# 517377                       NaN   NaN
# 517378                       NaN   NaN
# 517379                       NaN   NaN
# 517380                       NaN   NaN
# 517381                       NaN   NaN
# 517382                       NaN   NaN
# 517383                       NaN   NaN
# 517384                       NaN   NaN
# 517385                       NaN   NaN
# 517386                       NaN   NaN
# 517387                       NaN   NaN
# 517388                       NaN   NaN
# 517389                       NaN   NaN
# 517390                       NaN   NaN
# 517391                       NaN   NaN
# 517392                       NaN   NaN
# 517393                       NaN   NaN
# 517394                       NaN   NaN
# 517395                       NaN   NaN
# 517396                       NaN   NaN
# 517397                       NaN   NaN
# 517398                       NaN   NaN
# 517399                       NaN   NaN
# 517400                       NaN   NaN
#
#                                                  X-Folder    X-Origin  \
# 0       \Phillip_Allen_Jan2002_1\Allen, Phillip K.\'Se...     Allen-P
# 1       \Phillip_Allen_Jan2002_1\Allen, Phillip K.\'Se...     Allen-P
# 2         \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# 3         \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# 4         \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# 5         \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# 6         \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# 7         \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# 8         \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# 9         \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# 10        \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# 11        \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# 12        \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# 13        \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# 14        \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# 15        \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# 16        \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# 17      \Phillip_Allen_Jan2002_1\Allen, Phillip K.\'Se...     Allen-P
# 18        \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# 19        \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# 20        \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# 21        \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# 22        \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# 23        \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# 24        \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# 25        \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# 26        \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# 27        \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# 28      \Phillip_Allen_Jan2002_1\Allen, Phillip K.\'Se...     Allen-P
# 29        \Phillip_Allen_Dec2000\Notes Folders\'sent mail     Allen-P
# ...                                                   ...         ...
# 517371               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517372               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517373               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517374               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517375               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517376               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517377               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517378               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517379               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517380               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517381               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517382               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517383               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517384               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517385               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517386               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517387               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517388               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517389               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517390               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517391               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517392               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517393               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517394               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517395               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517396               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517397               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517398               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517399               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
# 517400               \ExMerge - Zufferli, John\Sent Items  ZUFFERLI-J
#
#                          X-FileName  \
# 0       pallen (Non-Privileged).pst
# 1       pallen (Non-Privileged).pst
# 2                        pallen.nsf
# 3                        pallen.nsf
# 4                        pallen.nsf
# 5                        pallen.nsf
# 6                        pallen.nsf
# 7                        pallen.nsf
# 8                        pallen.nsf
# 9                        pallen.nsf
# 10                       pallen.nsf
# 11                       pallen.nsf
# 12                       pallen.nsf
# 13                       pallen.nsf
# 14                       pallen.nsf
# 15                       pallen.nsf
# 16                       pallen.nsf
# 17      pallen (Non-Privileged).pst
# 18                       pallen.nsf
# 19                       pallen.nsf
# 20                       pallen.nsf
# 21                       pallen.nsf
# 22                       pallen.nsf
# 23                       pallen.nsf
# 24                       pallen.nsf
# 25                       pallen.nsf
# 26                       pallen.nsf
# 27                       pallen.nsf
# 28      pallen (Non-Privileged).pst
# 29                       pallen.nsf
# ...                             ...
# 517371    john zufferli 6-26-02.PST
# 517372    john zufferli 6-26-02.PST
# 517373    john zufferli 6-26-02.PST
# 517374    john zufferli 6-26-02.PST
# 517375    john zufferli 6-26-02.PST
# 517376    john zufferli 6-26-02.PST
# 517377    john zufferli 6-26-02.PST
# 517378    john zufferli 6-26-02.PST
# 517379    john zufferli 6-26-02.PST
# 517380    john zufferli 6-26-02.PST
# 517381    john zufferli 6-26-02.PST
# 517382    john zufferli 6-26-02.PST
# 517383    john zufferli 6-26-02.PST
# 517384    john zufferli 6-26-02.PST
# 517385    john zufferli 6-26-02.PST
# 517386    john zufferli 6-26-02.PST
# 517387    john zufferli 6-26-02.PST
# 517388    john zufferli 6-26-02.PST
# 517389    john zufferli 6-26-02.PST
# 517390    john zufferli 6-26-02.PST
# 517391    john zufferli 6-26-02.PST
# 517392    john zufferli 6-26-02.PST
# 517393    john zufferli 6-26-02.PST
# 517394    john zufferli 6-26-02.PST
# 517395    john zufferli 6-26-02.PST
# 517396    john zufferli 6-26-02.PST
# 517397    john zufferli 6-26-02.PST
# 517398    john zufferli 6-26-02.PST
# 517399    john zufferli 6-26-02.PST
# 517400    john zufferli 6-26-02.PST
#
#                                                   content        user
# 0                               Here is our forecast\n\n      allen-p
# 1       Traveling to have a business meeting takes the...     allen-p
# 2                          test successful.  way to go!!!     allen-p
# 3       Randy,\n\n Can you send me a schedule of the s...     allen-p
# 4                     Let's shoot for Tuesday at 11:45.       allen-p
# 5       Greg,\n\n How about either next Tuesday or Thu...     allen-p
# 6       Please cc the following distribution list with...     allen-p
# 7                        any morning between 10 and 11:30     allen-p
# 8       1. login:  pallen pw: ke9davis\n\n I don't thi...     allen-p
# 9       ---------------------- Forwarded by Phillip K ...     allen-p
# 10      Mr. Buckner,\n\n For delivered gas behind San ...     allen-p
# 11      Lucy,\n\n Here are the rentrolls:\n\n\n\n Open...     allen-p
# 12      ---------------------- Forwarded by Phillip K ...     allen-p
# 13      ---------------------- Forwarded by Phillip K ...     allen-p
# 14      Dave, \n\n Here are the names of the west desk...     allen-p
# 15               Paula,\n\n 35 million is fine\n\nPhillip     allen-p
# 16      ---------------------- Forwarded by Phillip K ...     allen-p
# 17      Tim,\n\nmike grigsby is having problems with a...     allen-p
# 18      ---------------------- Forwarded by Phillip K ...     allen-p
# 19      ---------------------- Forwarded by Phillip K ...     allen-p
# 20      Brenda,\n\nPlease use the second check as the ...     allen-p
# 21      I think Fletch has a good CPA.  I am still doi...     allen-p
# 22      Brenda,\n\n Please use the second check as my ...     allen-p
# 23      ---------------------- Forwarded by Phillip K ...     allen-p
# 24      Liane,\n\n As we discussed yesterday, I am con...     allen-p
# 25      ---------------------- Forwarded by Phillip K ...     allen-p
# 26      ---------------------- Forwarded by Phillip K ...     allen-p
# 27      ---------------------- Forwarded by Phillip K ...     allen-p
# 28      Reagan,\n\nJust wanted to give you an update. ...     allen-p
# 29      Nymex expiration is during this time frame.  P...     allen-p
# ...                                                   ...         ...
# 517371  Dad asked if I wanted to lend you some money b...  zufferli-j
# 517372  I am interested in a program for myself.  I am...  zufferli-j
# 517373  yes\n\n -----Original Message-----\nFrom: \tDu...  zufferli-j
# 517374  Its OK\n\nJohn Zufferli\n\n -----Original Mess...  zufferli-j
# 517375  you can increase the direct sale to include De...  zufferli-j
# 517376  You should talk to Jess about that, she is due...  zufferli-j
# 517377    \n\n -----Original Message-----\nFrom: \tCap...  zufferli-j
# 517378  Here is the update list that you requested. Mi...  zufferli-j
# 517379  i am waiting on the conference call and no one...  zufferli-j
# 517380  \n\n -----Original Message-----\nFrom: \tLivia...  zufferli-j
# 517381  \n\n -----Original Message-----\nFrom: \tMcKee...  zufferli-j
# 517382  nothing new here, when is your flight? have yo...  zufferli-j
# 517383  \nIn addition to a list of software and system...  zufferli-j
# 517384  Please set up access for the digital certifica...  zufferli-j
# 517385  \n\n -----Original Message-----\nFrom: \t"Ritt...  zufferli-j
# 517386  \n\n -----Original Message-----\nFrom: \t"John...  zufferli-j
# 517387  \n\n -----Original Message-----\nFrom: \tMilnt...  zufferli-j
# 517388  \nHere is the info for the commercial staff\n\...  zufferli-j
# 517389  \nEnron is willing to perform the operation un...  zufferli-j
# 517390  I will have 4 books:\n\nCAND-MGMT-BAS for all ...  zufferli-j
# 517391  \n\n -----Original Message-----\nFrom: \tReeve...  zufferli-j
# 517392  Nicole and everyone, I think the directory is ...  zufferli-j
# 517393  not yet, rob has been in the court house all d...  zufferli-j
# 517394  \n\n -----Original Message-----\nFrom: \t"Lern...  zufferli-j
# 517395  very busy, jess is ok just scared\n\n -----Ori...  zufferli-j
# 517396  This is a trade with OIL-SPEC-HEDGE-NG (John L...  zufferli-j
# 517397  Some of my position is with the Alberta Term b...  zufferli-j
# 517398  2\n\n -----Original Message-----\nFrom: \tDouc...  zufferli-j
# 517399  Analyst\t\t\t\t\tRank\n\nStephane Brodeur\t\t\...  zufferli-j
# 517400  i think the YMCA has a class that is for peopl...  zufferli-j
#
# [517401 rows x 19 columns]

# %%
df1 = df[['From','To']].copy()

# %%
def replace_all(eg):
    rep = {"(":"",
       ")":"",
      "{":"",
      "}":"",
      "'":"",
        '"':"",
      "frozenset":""}
    for i,j in rep.items():
        eg = eg.replace(i,j)
    return eg

# %%
df1['From'] = df1['From'].apply(lambda x : replace_all(str(x)))
df1['To'] = df1['To'].apply(lambda x : replace_all(str(x)))

# %%
cct = pd.concat([pd.Series(row['From'],row['To'].split(',')) for _,row in df1.iterrows()])

# %%
adj_mat1 = cct.reset_index()

# %%
adj_mat1.columns = ['To','From']
adj_mat1['tag'] = [i for i in range(3123028)]
adj_mat1.tail(5)
# Out:
#                                  To                     From      tag
# 3123023        kori.loibl@enron.com  john.zufferli@enron.com  3123023
# 3123024     john.lavorato@enron.com  john.zufferli@enron.com  3123024
# 3123025       dawn.doucet@enron.com  john.zufferli@enron.com  3123025
# 3123026      jeanie.slone@enron.com  john.zufferli@enron.com  3123026
# 3123027  livia_zufferli@monitor.com  john.zufferli@enron.com  3123027

# %%
# mt3 is pure enron
is_To_enron = [bool('@enron.com' in i) for i in adj_mat1['To']]
adj_mat2 = adj_mat1[is_To_enron].copy()
is_From_enron = [bool('@enron.com' in i) for i in adj_mat2['From']]
adj_mat3 = adj_mat2[is_From_enron].copy()

# %%
# get naive adj matrix
adj_mat3['From'] = adj_mat3['From'].apply(lambda x: re.sub(r'@.*','',x))
adj_mat3['To'] = adj_mat3['To'].apply(lambda x: re.sub(r'@.*','',x))
adj_mat = adj_mat3.drop('tag',axis=1).copy()

# %%
# DELETE emails address that is not a person's name 
adj_mat_cleaned_to = adj_mat[[bool(re.match(r'^[a-zA-Z]',x) and
                                (not re.match(r'.*\.\..*',x)) and
                               (not re.match(r'^all\..+',x)) and
                               re.match(r'.+\..+',x)) for x in adj_mat['To']]].copy()
adj_mat_cleaned_all = adj_mat_cleaned_to[[bool(re.match(r'^[a-zA-Z]',x) and
                                (not re.match(r'.*\.\..*',x)) and
                               (not re.match(r'^all\..+',x)) and
                               re.match(r'.+\..+',x)) for x in adj_mat_cleaned_to['From']]].copy()

# %%
grouped_mat = adj_mat_cleaned_all.groupby(['From','To']).size().reset_index().copy()

# %%
# edge count bigger than n
n = 100
grouped_mat.columns = ['From','To','Count']
gm_count_btn = grouped_mat[grouped_mat['Count'] > n].copy()
gm_count_btn.head()
# Out:
#                 From               To  Count
# 113     aimee.lannou     daren.farmer    207
# 303     aleck.dadson  richard.shapiro    121
# 495  amanda.rybarski       mike.maggi    137
# 523      ami.chokshi     daren.farmer    110
# 526      ami.chokshi     george.grant    153

# %%
g=nx.from_pandas_dataframe(gm_count_btn,'From','To','Count')

# %%
weights = np.array([n['Count'] for (a,b,n) in g.edges(data=True)])
max = np.max(weights); min = np.min(weights)
weights_scaled = (weights-min)/(max-min)
selected_dict = {}
values = sorted([ v for v in nx.degree(g).values()])
for key,value in nx.degree(g).items():
    if value > values[-10]:
        selected_dict[key] = key

# %%
dict = nx.degree_centrality(g)
a=sorted(dict,key=dict.__getitem__,reverse=True)[:10]

# %%
dict = nx.closeness_centrality(g)
b=sorted(dict,key=dict.__getitem__,reverse=True)[:10]

# %%
dict = nx.betweenness_centrality(g)
c=sorted(dict,key=dict.__getitem__,reverse=True)[:10]

# %%
set(a).intersection(set(b)).intersection(set(c))
# Out:
# {'kay.mann', 'sara.shackleton', 'tana.jones'}

# %%
nodes_closeness_sort = sorted(nx.closeness_centrality(g),key=nx.closeness_centrality(g).get,reverse=True)
nodes_closeness_sort[:5]
# Out:
# ['mark.taylor',
#  'louise.kitchen',
#  'mark.haedicke',
#  'david.delainey',
#  'john.lavorato']

# %%
g=nx.from_pandas_dataframe(gm_count_btn,'From','To','Count')
weights = nx.get_edge_attributes(g,'Count')
plt.figure(figsize=(8,8)) 
node_position = nx.spring_layout(g,iterations=30)
nx.draw(g,pos= node_position,
        node_color='yellow', 
        with_labels= 0,
        nodelist = [k for k in nx.degree(g).keys()],
        node_size = [v*15 for v in nx.degree(g).values()],
        
        alpha=0.7,edge_color='black',
        width=weights_scaled*50+0.1)
labels = {}
nx.draw_networkx_nodes(g, pos=node_position, nodelist=selected_dict,node_color='red')
nx.draw_networkx_labels(g, pos=node_position, 
                        labels=selected_dict,
                        font_color = 'black',
                        font_size=16)
plt.show()

# %% [markdown]
# ### egocentric
# - lower threshold to 5, so that can get more info

# %%
n = 15
grouped_mat.columns = ['From','To','Count']
gm_count_btn = grouped_mat[grouped_mat['Count'] > n].copy()
gm_count_btn.head()
# Out:
#                     From                       To  Count
# 29          adam.johnson               sean.boyle     50
# 49           admin.enron                eric.bass     26
# 63  administration.enron  maintenance.dl-exchange     56
# 66           adnan.patel            karen.lambert     22
# 96       adrianne.engler           jonathan.mckay     18

# %%
# test name and find out explicit address
name = 'bill.williams'
# gm_count_btn[[(name in x) or (name in y) for x,y in zip(gm_count_btn['To'],gm_count_btn['From'])]]

# %% [markdown]
# - mastermind email address
#     - '	jeff.skilling'
#     - '	kenneth.lay'
#     - 'tim.belden'
#     - ‘bill.williams’

# %%
name = 'jeff.skilling'
g2=nx.from_pandas_dataframe(gm_count_btn,'From','To','Count')

g_ego = nx.ego_graph(g2,name,radius=1,center=True)
plt.figure(figsize=(8,8))
# nodes_position = nx.spring_layout(g_ego,iterations=10)
nodes_position = nx.fruchterman_reingold_layout(g_ego)

weights = np.array([n['Count'] for (a,b,n) in g2.edges(data=True)])
max = np.max(weights); min = np.min(weights)
weights_scaled = (weights-min)/(max-min)

nx.draw(g_ego,pos=nodes_position,width=weights_scaled*50+1,node_color='yellow')

nx.draw_networkx_nodes(g, pos=nodes_position, 
                       nodelist={name:name},
                       node_size = 800,
                       node_color='red')

nx.draw_networkx_labels(g_ego, pos=nodes_position, 
                        font_color = 'black',
                        font_size=16)
plt.show()

# %%
name = 'kenneth.lay'
g2=nx.from_pandas_dataframe(gm_count_btn,'From','To','Count')

g_ego = nx.ego_graph(g2,name,radius=1,center=True)
plt.figure(figsize=(8,8))
# nodes_position = nx.spring_layout(g_ego,iterations=10)
nodes_position = nx.fruchterman_reingold_layout(g_ego)

weights = np.array([n['Count'] for (a,b,n) in g2.edges(data=True)])
max = np.max(weights); min = np.min(weights)
weights_scaled = (weights-min)/(max-min)

nx.draw(g_ego,pos=nodes_position,width=weights_scaled*50+1,node_color='yellow')

nx.draw_networkx_nodes(g, pos=nodes_position, 
                       nodelist={name:name},
                       node_size = 800,
                       node_color='red')

nx.draw_networkx_labels(g_ego, pos=nodes_position, 
                        font_color = 'black',
                        font_size=16)
plt.show()

# %%
name = 'tim.belden'
g2=nx.from_pandas_dataframe(gm_count_btn,'From','To','Count')

g_ego = nx.ego_graph(g2,name,radius=1,center=True)
plt.figure(figsize=(8,8))
# nodes_position = nx.spring_layout(g_ego,iterations=10)
nodes_position = nx.fruchterman_reingold_layout(g_ego)

weights = np.array([n['Count'] for (a,b,n) in g2.edges(data=True)])
max = np.max(weights); min = np.min(weights)
weights_scaled = (weights-min)/(max-min)

nx.draw(g_ego,pos=nodes_position,width=weights_scaled*50+1,node_color='yellow')

nx.draw_networkx_nodes(g, pos=nodes_position, 
                       nodelist={name:name},
                       node_size = 800,
                       node_color='red')

nx.draw_networkx_labels(g_ego, pos=nodes_position, 
                        font_color = 'black',
                        font_size=16)
plt.show()

# %%
name = 'bill.williams'
g2=nx.from_pandas_dataframe(gm_count_btn,'From','To','Count')

g_ego = nx.ego_graph(g2,name,radius=1,center=True)
plt.figure(figsize=(8,8))
# nodes_position = nx.spring_layout(g_ego,iterations=10)
nodes_position = nx.fruchterman_reingold_layout(g_ego)

weights = np.array([n['Count'] for (a,b,n) in g2.edges(data=True)])
max = np.max(weights); min = np.min(weights)
weights_scaled = (weights-min)/(max-min)

nx.draw(g_ego,pos=nodes_position,width=weights_scaled*50+1,node_color='yellow')

nx.draw_networkx_nodes(g, pos=nodes_position, 
                       nodelist={name:name},
                       node_size = 800,
                       node_color='red')

nx.draw_networkx_labels(g_ego, pos=nodes_position, 
                        font_color = 'black',
                        font_size=16)
plt.show()

# %% [markdown]
# ### centiment analysis

# %%
from textblob import TextBlob

# %%
content_people_one = df[['kay.mann' in x for x in df['From']]][['Date','content']].copy()

# %%
content_people_one
# Out:
#                                          Date  \
# 9506     Mon, 4 Feb 2002 14:16:59 -0800 (PST)
# 9863    Tue, 22 Jan 2002 09:09:55 -0800 (PST)
# 9896    Mon, 28 Jan 2002 11:54:59 -0800 (PST)
# 128159  Thu, 28 Mar 2002 12:46:54 -0800 (PST)
# 128162  Thu, 28 Mar 2002 06:49:42 -0800 (PST)
# 128163  Thu, 28 Mar 2002 06:27:52 -0800 (PST)
# 128166  Wed, 27 Mar 2002 12:34:16 -0800 (PST)
# 128169  Wed, 27 Mar 2002 10:47:40 -0800 (PST)
# 128193   Wed, 6 Mar 2002 12:02:01 -0800 (PST)
# 128300  Tue, 19 Feb 2002 15:43:14 -0800 (PST)
# 128309   Wed, 1 May 2002 13:36:52 -0700 (PDT)
# 128311  Tue, 30 Apr 2002 10:09:53 -0700 (PDT)
# 128313  Tue, 30 Apr 2002 09:07:24 -0700 (PDT)
# 128346  Mon, 20 May 2002 08:09:45 -0700 (PDT)
# 128363  Mon, 25 Feb 2002 11:36:09 -0800 (PST)
# 128428  Tue, 28 May 2002 15:02:28 -0700 (PDT)
# 152091  Tue, 26 Sep 2000 10:51:00 -0700 (PDT)
# 153233  Mon, 25 Sep 2000 09:47:00 -0700 (PDT)
# 154090  Mon, 25 Sep 2000 09:47:00 -0700 (PDT)
# 155213  Tue, 26 Sep 2000 10:51:00 -0700 (PDT)
# 169613  Fri, 19 Oct 2001 04:59:35 -0700 (PDT)
# 169658  Mon, 22 Oct 2001 14:20:33 -0700 (PDT)
# 169887  Thu, 20 Dec 2001 11:03:37 -0800 (PST)
# 169889  Thu, 27 Dec 2001 05:38:25 -0800 (PST)
# 169911  Wed, 14 Nov 2001 14:05:28 -0800 (PST)
# 169932  Wed, 14 Nov 2001 10:15:41 -0800 (PST)
# 169933  Wed, 14 Nov 2001 11:43:21 -0800 (PST)
# 170460   Thu, 6 Dec 2001 18:22:14 -0800 (PST)
# 170618  Tue, 27 Nov 2001 07:20:57 -0800 (PST)
# 170627  Tue, 27 Nov 2001 12:13:49 -0800 (PST)
# ...                                       ...
# 386224  Thu, 27 Dec 2001 05:38:25 -0800 (PST)
# 386627  Mon, 16 Jul 2001 16:01:27 -0700 (PDT)
# 386662  Wed, 14 Nov 2001 14:05:28 -0800 (PST)
# 386677  Mon, 19 Nov 2001 14:43:34 -0800 (PST)
# 386704  Tue, 27 Nov 2001 15:38:16 -0800 (PST)
# 387003  Mon, 22 Oct 2001 14:20:33 -0700 (PDT)
# 387099  Mon, 19 Nov 2001 15:26:28 -0800 (PST)
# 387270  Tue, 15 May 2001 03:59:00 -0700 (PDT)
# 387283  Fri, 11 May 2001 06:53:00 -0700 (PDT)
# 387297   Tue, 8 May 2001 04:40:00 -0700 (PDT)
# 387324  Tue, 10 Oct 2000 07:19:00 -0700 (PDT)
# 387691  Wed, 16 May 2001 02:41:00 -0700 (PDT)
# 387707  Mon, 14 May 2001 05:30:00 -0700 (PDT)
# 387740   Tue, 8 May 2001 06:23:00 -0700 (PDT)
# 387880   Mon, 8 Jan 2001 04:50:00 -0800 (PST)
# 395670  Wed, 26 Dec 2001 09:20:27 -0800 (PST)
# 415754  Tue, 29 Aug 2000 12:09:00 -0700 (PDT)
# 415760  Wed, 30 Aug 2000 01:49:00 -0700 (PDT)
# 416685   Thu, 5 Oct 2000 02:01:00 -0700 (PDT)
# 420852   Fri, 8 Mar 2002 09:35:44 -0800 (PST)
# 420902  Wed, 20 Mar 2002 08:39:29 -0800 (PST)
# 421760   Wed, 9 Jan 2002 14:01:57 -0800 (PST)
# 421784  Mon, 14 Jan 2002 08:48:33 -0800 (PST)
# 421788  Mon, 14 Jan 2002 15:23:58 -0800 (PST)
# 421799  Tue, 15 Jan 2002 15:23:07 -0800 (PST)
# 422812  Wed, 30 Aug 2000 01:49:00 -0700 (PDT)
# 422815  Tue, 29 Aug 2000 12:09:00 -0700 (PDT)
# 425509   Thu, 5 Oct 2000 02:01:00 -0700 (PDT)
# 450321  Tue, 28 Nov 2000 04:38:00 -0800 (PST)
# 451784  Tue, 28 Nov 2000 04:38:00 -0800 (PST)
#
#                                                   content  polarity  \
# 9506    We are in a loop.  We need a process to deal w...  0.200000
# 9863    I'm looking for ISDA's between Enron MW and EN...  0.050000
# 9896    Could I get a copy of the Midland Cogeneration...  0.064286
# 128159                      Here's a revised letter:\n\n   0.000000
# 128162  We can work with it either way. \n------------...  0.000000
# 128163  Dominion's lawyer left me a message that they ... -0.009375
# 128166  comments?\n\n \n\nI've sent this to Mark E as ...  0.000000
# 128169  I've left a message for Dominion's counsel, te...  0.037153
# 128193  If is was an ENA deal, the Dec. 3 is correct p...  0.065797
# 128300  Shemin Proctor (an outside lawyer who is helpi...  0.045629
# 128309  chip schneider makes that call.\n-------------...  0.000000
# 128311  My understanding is that the EPNG contract ter...  0.058114
# 128313  I spoke with Chip.  This can be presented to t...  0.167361
# 128346  Ruth, this was before my time, but I can check...  0.035903
# 128363  Mark Ellenberg is working on the response.\n\n...  0.020871
# 128428                 Meeting location to be determined.  0.000000
# 152091  FYI.  I'll bring you the ONSI confidentiality ...  0.040146
# 153233  This is an internal draft, which has not been ...  0.015278
# 154090  This is an internal draft, which has not been ...  0.015278
# 155213  FYI.  I'll bring you the ONSI confidentiality ...  0.040146
# 169613  You try and see if he notices.\n\n -----Origin...  0.062500
# 169658  My brother just called, and my dad has just be...  0.130000
# 169887  I would like to take Dec 26, 31 and Jan. 2 as ...  0.100000
# 169889  I'm going to take today as a vacation day, sin...  0.066667
# 169911  I'm in the Enron Basics of Risk Management sem...  0.066667
# 169932  I know there's a lot of anxiety about severanc...  0.021429
# 169933  http://www.corporate-ir.net/ireye/ir_site.zhtm...  0.000000
# 170460  I can do that, especially if I get the list ea...  0.043056
# 170618  \n\n -----Original Message-----\nFrom: \tWrigh...  0.152847
# 170627  Jeff,\n\nWhat's your suggestion?  We are looki...  0.109307
# ...                                                   ...       ...
# 386224  I'm going to take today as a vacation day, sin...  0.066667
# 386627  As requested.\n\n-----Original Message-----\nF...  0.101190
# 386662  I'm in the Enron Basics of Risk Management sem...  0.066667
# 386677  Kinda wish Kortney would have talked to me and...  0.068553
# 386704  In the interest of moving things forward, it w...  0.086742
# 387003  My brother just called, and my dad has just be...  0.130000
# 387099  \n\n -----Original Message-----\nFrom: \tBrown...  0.032110
# 387270  Due to the size of this possible transaction, ...  0.115025
# 387283  John still wants to hold off on a document rev...  0.109921
# 387297  FYI. Certain aspects of this presentation will...  0.126644
# 387324  This was sent to me by one of the developers. ...  0.126431
# 387691  Taking asset management to a new level of pain...  0.033838
# 387707  FYI.  I've reviewing at Heather's request.\n\n...  0.160764
# 387740  Steve/Christian,\n\nThe attached file is a dra...  0.050000
# 387880  Hi Elizabeth,\n\nI've had a couple of originat...  0.026563
# 395670  I will tell them.  Thanks.\n------------------...  0.066667
# 415754  Sara,\n\nMaybe a conference call with Gregg wo...  0.086111
# 415760  Feels funny emailing someone so close.  I'm ad...  0.000833
# 416685  Gregg,\n\nIt is my understanding that Enron an...  0.119048
# 420852   \n-----Original Message-----\nFrom: Kroll, He...  0.015243
# 420902  I will be out of office the week of March 18th...  0.166667
# 421760  Here's a bankruptcy calendar.  You might have ...  0.000000
# 421784  I've learned that there is a netting agreement...  0.000000
# 421788  Good for me.\n\n -----Original Message-----\nF...  0.031667
# 421799  Sara,\n\nLooks like one of yours.\n\nKay\n\n -...  0.071615
# 422812  Feels funny emailing someone so close.  I'm ad...  0.000833
# 422815  Sara,\n\nMaybe a conference call with Gregg wo...  0.086111
# 425509  Gregg,\n\nIt is my understanding that Enron an...  0.119048
# 450321  Hi Carol,\n\nI saw that you posted about getti...  0.283333
# 451784  Hi Carol,\n\nI saw that you posted about getti...  0.283333
#
#        date_formated
# 9506      2002-02-04
# 9863      2002-01-22
# 9896      2002-01-28
# 128159    2002-03-28
# 128162    2002-03-28
# 128163    2002-03-28
# 128166    2002-03-27
# 128169    2002-03-27
# 128193    2002-03-06
# 128300    2002-02-19
# 128309    2002-05-01
# 128311    2002-04-30
# 128313    2002-04-30
# 128346    2002-05-20
# 128363    2002-02-25
# 128428    2002-05-28
# 152091    2000-09-26
# 153233    2000-09-25
# 154090    2000-09-25
# 155213    2000-09-26
# 169613    2001-10-19
# 169658    2001-10-22
# 169887    2001-12-20
# 169889    2001-12-27
# 169911    2001-11-14
# 169932    2001-11-14
# 169933    2001-11-14
# 170460    2001-12-06
# 170618    2001-11-27
# 170627    2001-11-27
# ...              ...
# 386224    2001-12-27
# 386627    2001-07-16
# 386662    2001-11-14
# 386677    2001-11-19
# 386704    2001-11-27
# 387003    2001-10-22
# 387099    2001-11-19
# 387270    2001-05-15
# 387283    2001-05-11
# 387297    2001-05-08
# 387324    2000-10-10
# 387691    2001-05-16
# 387707    2001-05-14
# 387740    2001-05-08
# 387880    2001-01-08
# 395670    2001-12-26
# 415754    2000-08-29
# 415760    2000-08-30
# 416685    2000-10-05
# 420852    2002-03-08
# 420902    2002-03-20
# 421760    2002-01-09
# 421784    2002-01-14
# 421788    2002-01-14
# 421799    2002-01-15
# 422812    2000-08-30
# 422815    2000-08-29
# 425509    2000-10-05
# 450321    2000-11-28
# 451784    2000-11-28
#
# [16737 rows x 4 columns]

# %%
from dateutil import parser
import datetime
def format_date(str):
    dt_obj = parser.parse(str)
    return  datetime.date(dt_obj.year,dt_obj.month,dt_obj.day)

# %%
def get_content_polarity(content):
    blob = TextBlob(content)
    sentences_polarity = []
    for sentence in blob.sentences:
        sentences_polarity.append(sentence.sentiment.polarity)
    return np.mean(sentences_polarity)
content_people_one['polarity'] = content_people_one['content'].apply(lambda x:get_content_polarity(x))

# %%
content_people_one['date_formated'] = content_people_one['Date'].apply(lambda x: format_date(x))

# %%
date_polarity = content_people_one.groupby('date_formated').agg({'polarity':np.mean}).reset_index()[1:]

# %%
date_polarity
# Out:
#     date_formated  polarity
# 1      2000-06-02  0.056561
# 2      2000-06-05  0.016171
# 3      2000-06-06  0.051254
# 4      2000-06-07 -0.048333
# 5      2000-06-08  0.056332
# 6      2000-06-09 -0.005564
# 7      2000-06-12  0.000546
# 8      2000-06-13  0.056907
# 9      2000-06-15  0.080312
# 10     2000-06-16  0.120655
# 11     2000-06-19  0.054219
# 12     2000-06-20  0.086011
# 13     2000-06-21  0.054001
# 14     2000-06-22  0.055924
# 15     2000-06-23  0.125525
# 16     2000-06-26  0.129332
# 17     2000-07-05  0.010488
# 18     2000-07-06  0.081908
# 19     2000-07-07  0.020581
# 20     2000-07-10  0.035232
# 21     2000-07-11  0.080080
# 22     2000-07-12  0.086704
# 23     2000-07-13  0.031515
# 24     2000-07-14  0.046305
# 25     2000-07-15  0.040813
# 26     2000-07-16 -0.008974
# 27     2000-07-17  0.062604
# 28     2000-07-18  0.049607
# 29     2000-07-19  0.081556
# 30     2000-07-20  0.052980
# ..            ...       ...
# 316    2001-12-14  0.065397
# 317    2001-12-15  0.195000
# 318    2001-12-17  0.115281
# 319    2001-12-18  0.016146
# 320    2001-12-19  0.042045
# 321    2001-12-20  0.078970
# 322    2001-12-21  0.054956
# 323    2001-12-26  0.108333
# 324    2001-12-27 -0.017980
# 325    2001-12-28  0.075198
# 326    2001-12-31 -0.022222
# 327    2002-01-09  0.000000
# 328    2002-01-14  0.015833
# 329    2002-01-15  0.071615
# 330    2002-01-22  0.050000
# 331    2002-01-28  0.064286
# 332    2002-02-04  0.200000
# 333    2002-02-07  0.031624
# 334    2002-02-19  0.045629
# 335    2002-02-25  0.020871
# 336    2002-03-06  0.065797
# 337    2002-03-08  0.015243
# 338    2002-03-20  0.166667
# 339    2002-03-26  0.037731
# 340    2002-03-27  0.018576
# 341    2002-03-28 -0.003125
# 342    2002-04-30  0.112738
# 343    2002-05-01  0.000000
# 344    2002-05-20  0.035903
# 345    2002-05-28  0.000000
#
# [345 rows x 2 columns]

# %%
# %matplotlib inline
plt.figure(figsize=(12,8)) 
plt.plot(date_polarity['date_formated'],date_polarity['polarity'])
plt.plot(date_polarity['date_formated'],np.zeros(date_polarity.shape[0]),color='r')

# %%
content_people_two = df[['sara.shackleton' in x for x in df['From']]][['Date','content']].copy()
content_people_two['date_formated'] = content_people_two['Date'].apply(lambda x: format_date(x))
content_people_two['polarity'] = content_people_two['content'].apply(lambda x:get_content_polarity(x))
date_polarity2 = content_people_two.groupby('date_formated').agg({'polarity':np.mean}).reset_index()

# %%
date_polarity2 = date_polarity2[1:]

# %%
plt.figure(figsize=(12,8)) 
plt.plot(date_polarity2['date_formated'],date_polarity2['polarity'])
plt.plot(date_polarity2['date_formated'],np.zeros(date_polarity2.shape[0]),color='r')

# %%
content_people_three = df[['tana.jones' in x for x in df['From']]][['Date','content']].copy()
content_people_three['date_formated'] = content_people_three['Date'].apply(lambda x: format_date(x))
content_people_three['polarity'] = content_people_three['content'].apply(lambda x:get_content_polarity(x))
date_polarity3 = content_people_three.groupby('date_formated').agg({'polarity':np.mean}).reset_index()

# %%
date_polarity3 = date_polarity3[1:]

# %%
plt.figure(figsize=(12,8)) 
line = plt.plot(date_polarity3['date_formated'],date_polarity3['polarity'])
threshold = plt.plot(date_polarity3['date_formated'],np.zeros(date_polarity3.shape[0]),color='r')
# from scipy.interpolate import interp1d
# smoothed = interp1d(date_polarity3['date_formated'], date_polarity3['polarity'], kind='cubic')
